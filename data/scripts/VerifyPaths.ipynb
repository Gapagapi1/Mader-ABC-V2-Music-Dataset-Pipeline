# %%
import os
import json

# %%
new_root = "lmd_matched_flat"

# %%
with open("md5_to_paths.json", "r") as json_file:
    path_data = json.load(json_file)

# %%
with open("versions.json", "r") as json_file:
    versions_data = json.load(json_file)

# %%
for md5_list in versions_data.values():
    for md5 in md5_list:
        if md5 not in path_data:
            print(md5)
