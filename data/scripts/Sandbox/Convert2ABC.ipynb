# %%
import os
import mido
import subprocess

# %%
new_root = "../../midi/lmd_matched_genre"
abc_root = "../../midi/lmd_matched_flat_abc_test"

# %%
os.makedirs(abc_root)

# %%
wrong_files = []

# %%
for root, folders, files in os.walk(new_root):
    for file in files:
        midi_path = os.path.join(root, file)
        abc_folder = os.path.join(abc_root, root.replace(new_root + "/", ""))
        abc_path = os.path.join(abc_folder, file.replace(".midi", ".abc").replace(".mid", ".abc"))
        
        # L:1/1 | -K:C | one bar per line | no lyrics
        command = "midi2abc.exe -f {} -aul 1 -k 0 -obpl -nogr -noly -o {}".format(midi_path, abc_path)

        os.makedirs(abc_folder, exist_ok=True)
        
        try:
            subprocess.check_output(command, shell=True, timeout=3)
        except subprocess.CalledProcessError as e:
            wrong_files.append(midi_path)
            print(f"Error executing command on {midi_path}: {e}")
# Out:
# Error executing command on ../../midi/lmd_matched_genre/TRABBNH128F93392A1/62f4d8788ba05f3c49ebfa6fc9164621.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRABBNH128F93392A1/62f4d8788ba05f3c49ebfa6fc9164621.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRABBNH128F93392A1/62f4d8788ba05f3c49ebfa6fc9164621.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRACPEN128F4293F01/c7322533636b55d8eb7feb62bb7a2256.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRACPEN128F4293F01/c7322533636b55d8eb7feb62bb7a2256.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRACPEN128F4293F01/c7322533636b55d8eb7feb62bb7a2256.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAFMVN128F147CBCE/9d62a73bf682618b0cb387fa484d8951.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAFMVN128F147CBCE/9d62a73bf682618b0cb387fa484d8951.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAFMVN128F147CBCE/9d62a73bf682618b0cb387fa484d8951.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAFXZH128F4262D0A/39a063283db8902fab12e5b57c2fc285.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAFXZH128F4262D0A/39a063283db8902fab12e5b57c2fc285.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAFXZH128F4262D0A/39a063283db8902fab12e5b57c2fc285.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAGKTK128F42968B2/16bc4fc2113eb6451822224968c7fb24.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAGKTK128F42968B2/16bc4fc2113eb6451822224968c7fb24.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAGKTK128F42968B2/16bc4fc2113eb6451822224968c7fb24.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAGOAA128F422214B/7d36cb4fb85945912f1919237ba36f2b.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAGOAA128F422214B/7d36cb4fb85945912f1919237ba36f2b.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAGOAA128F422214B/7d36cb4fb85945912f1919237ba36f2b.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAGPKF128F427B439/7244bce006707eed0c3b276e469837dc.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAGPKF128F427B439/7244bce006707eed0c3b276e469837dc.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAGPKF128F427B439/7244bce006707eed0c3b276e469837dc.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAHACR128F14695DB/231e9c40217ee0844ac957c7ad185c39.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAHACR128F14695DB/231e9c40217ee0844ac957c7ad185c39.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAHACR128F14695DB/231e9c40217ee0844ac957c7ad185c39.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAIQNE128F423851B/e1e91033559d0038615cbd550361f505.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAIQNE128F423851B/e1e91033559d0038615cbd550361f505.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAIQNE128F423851B/e1e91033559d0038615cbd550361f505.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAJIEU128F429B613/a375323d7324fb1bf4f8697513b27c8e.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAJIEU128F429B613/a375323d7324fb1bf4f8697513b27c8e.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAJIEU128F429B613/a375323d7324fb1bf4f8697513b27c8e.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAJKQZ128F1465490/539e5566a50e16fc46c35f118ae3eca8.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAJKQZ128F1465490/539e5566a50e16fc46c35f118ae3eca8.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAJKQZ128F1465490/539e5566a50e16fc46c35f118ae3eca8.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAKFNJ128F42803A9/a37742bc4c70c0a633a457f658a14270.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAKFNJ128F42803A9/a37742bc4c70c0a633a457f658a14270.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAKFNJ128F42803A9/a37742bc4c70c0a633a457f658a14270.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRALECB128F42A35E8/dd9555116b47167117cf109db9a2d187.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRALECB128F42A35E8/dd9555116b47167117cf109db9a2d187.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRALECB128F42A35E8/dd9555116b47167117cf109db9a2d187.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRALZTM128F92EC5F0/1ed2b0a7993fabca5600e5edeef65e78.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRALZTM128F92EC5F0/1ed2b0a7993fabca5600e5edeef65e78.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRALZTM128F92EC5F0/1ed2b0a7993fabca5600e5edeef65e78.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRALZTM128F92EC5F0/a07d50baf8915e1b712081d2670c3c89.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRALZTM128F92EC5F0/a07d50baf8915e1b712081d2670c3c89.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRALZTM128F92EC5F0/a07d50baf8915e1b712081d2670c3c89.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRANFUR128F92D30FC/33e22470ea82991411457e237ac03628.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRANFUR128F92D30FC/33e22470ea82991411457e237ac03628.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRANFUR128F92D30FC/33e22470ea82991411457e237ac03628.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRANHSO12903CF02CC/c7322533636b55d8eb7feb62bb7a2256.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRANHSO12903CF02CC/c7322533636b55d8eb7feb62bb7a2256.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRANHSO12903CF02CC/c7322533636b55d8eb7feb62bb7a2256.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRANKSP128F425A9B8/c7322533636b55d8eb7feb62bb7a2256.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRANKSP128F425A9B8/c7322533636b55d8eb7feb62bb7a2256.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRANKSP128F425A9B8/c7322533636b55d8eb7feb62bb7a2256.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAOJYI128F42AD95E/ebc0be1c566dfc49f085fb018095957a.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAOJYI128F42AD95E/ebc0be1c566dfc49f085fb018095957a.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAOJYI128F42AD95E/ebc0be1c566dfc49f085fb018095957a.abc' returned non-zero exit status 3221225477.
# Error executing command on ../../midi/lmd_matched_genre/TRAONMM128F92DF7B0/433081510f6924fee7c72ed34809a910.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAONMM128F92DF7B0/433081510f6924fee7c72ed34809a910.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAONMM128F92DF7B0/433081510f6924fee7c72ed34809a910.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAONMM128F92DF7B0/5ca2cd2ba183ab92279b8a4f3246db89.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAONMM128F92DF7B0/5ca2cd2ba183ab92279b8a4f3246db89.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAONMM128F92DF7B0/5ca2cd2ba183ab92279b8a4f3246db89.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAONMM128F92DF7B0/abc5f5e3440e5a898a923291bf8c58e8.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAONMM128F92DF7B0/abc5f5e3440e5a898a923291bf8c58e8.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAONMM128F92DF7B0/abc5f5e3440e5a898a923291bf8c58e8.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAONMM128F92DF7B0/d293e6ac5072ededfbd0ee2dd7280447.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAONMM128F92DF7B0/d293e6ac5072ededfbd0ee2dd7280447.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAONMM128F92DF7B0/d293e6ac5072ededfbd0ee2dd7280447.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAOUDE128F42BC7F1/d06b28475991cb81bfb03452d9688c32.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAOUDE128F42BC7F1/d06b28475991cb81bfb03452d9688c32.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAOUDE128F42BC7F1/d06b28475991cb81bfb03452d9688c32.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAQEDY128F1466365/71c2bf60a040845e26ccfdbbbf994954.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAQEDY128F1466365/71c2bf60a040845e26ccfdbbbf994954.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAQEDY128F1466365/71c2bf60a040845e26ccfdbbbf994954.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAREYA128F932AD75/64b53e1dc28ac96bc4a860ada0021bb0.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAREYA128F932AD75/64b53e1dc28ac96bc4a860ada0021bb0.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAREYA128F932AD75/64b53e1dc28ac96bc4a860ada0021bb0.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRARPXT128F425FDF9/443164186d4fc69a055fae628fbeef3b.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRARPXT128F425FDF9/443164186d4fc69a055fae628fbeef3b.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRARPXT128F425FDF9/443164186d4fc69a055fae628fbeef3b.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRARREW128F92CD3D9/96724c4287a321e41251256a6b5bf61b.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRARREW128F92CD3D9/96724c4287a321e41251256a6b5bf61b.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRARREW128F92CD3D9/96724c4287a321e41251256a6b5bf61b.abc' returned non-zero exit status 3221225477.
# Error executing command on ../../midi/lmd_matched_genre/TRASFLP12903CBD8EC/64f2259fe689bd6c8e73b0dd06ed473b.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRASFLP12903CBD8EC/64f2259fe689bd6c8e73b0dd06ed473b.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRASFLP12903CBD8EC/64f2259fe689bd6c8e73b0dd06ed473b.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRASFLP12903CBD8EC/b2a141e8339b0698b3e1bfe55e6288aa.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRASFLP12903CBD8EC/b2a141e8339b0698b3e1bfe55e6288aa.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRASFLP12903CBD8EC/b2a141e8339b0698b3e1bfe55e6288aa.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRASICW128F146E6E1/b7891e7cf7740b0f36b213d1e482f721.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRASICW128F146E6E1/b7891e7cf7740b0f36b213d1e482f721.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRASICW128F146E6E1/b7891e7cf7740b0f36b213d1e482f721.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRASWFP128E0789E6C/f9ec92569365af3ab8b22e80330d9fa5.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRASWFP128E0789E6C/f9ec92569365af3ab8b22e80330d9fa5.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRASWFP128E0789E6C/f9ec92569365af3ab8b22e80330d9fa5.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRATTTF128F42621FE/f2395741b28e1af7f10d52396fbb5456.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRATTTF128F42621FE/f2395741b28e1af7f10d52396fbb5456.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRATTTF128F42621FE/f2395741b28e1af7f10d52396fbb5456.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAULTS128F931290B/134f962a9ef346e8132828cb4a69d6f3.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAULTS128F931290B/134f962a9ef346e8132828cb4a69d6f3.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAULTS128F931290B/134f962a9ef346e8132828cb4a69d6f3.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAWCOR128F4243CE7/0fce11c585fb2c69b83cde9167a01a99.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAWCOR128F4243CE7/0fce11c585fb2c69b83cde9167a01a99.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAWCOR128F4243CE7/0fce11c585fb2c69b83cde9167a01a99.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAWCOR128F4243CE7/8ef5dd1d523dbfc6a362597ad681dc3f.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAWCOR128F4243CE7/8ef5dd1d523dbfc6a362597ad681dc3f.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAWCOR128F4243CE7/8ef5dd1d523dbfc6a362597ad681dc3f.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAXQYP128F930458D/06d3f391e5dd969343b70d13c56afb20.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAXQYP128F930458D/06d3f391e5dd969343b70d13c56afb20.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAXQYP128F930458D/06d3f391e5dd969343b70d13c56afb20.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAXQYP128F930458D/c43ddafc53929cb5cfabce325ee40c44.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAXQYP128F930458D/c43ddafc53929cb5cfabce325ee40c44.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAXQYP128F930458D/c43ddafc53929cb5cfabce325ee40c44.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAXRXT12903CB0108/f1da2d486764c8340b20a10f1e228216.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAXRXT12903CB0108/f1da2d486764c8340b20a10f1e228216.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAXRXT12903CB0108/f1da2d486764c8340b20a10f1e228216.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAYFDQ128F145FB6B/19fcad888877033d94db999db87f055c.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAYFDQ128F145FB6B/19fcad888877033d94db999db87f055c.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAYFDQ128F145FB6B/19fcad888877033d94db999db87f055c.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAYFDQ128F145FB6B/8e0e304acdaafa105f7fba6b4dee0513.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAYFDQ128F145FB6B/8e0e304acdaafa105f7fba6b4dee0513.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAYFDQ128F145FB6B/8e0e304acdaafa105f7fba6b4dee0513.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAYJOF128F92F9EEA/515a5fa4b1844f3932bbc5a323c4a430.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAYJOF128F92F9EEA/515a5fa4b1844f3932bbc5a323c4a430.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAYJOF128F92F9EEA/515a5fa4b1844f3932bbc5a323c4a430.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAZASM128F932FBEE/1efd2dce75377860b97989d70a596a9c.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAZASM128F932FBEE/1efd2dce75377860b97989d70a596a9c.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAZASM128F932FBEE/1efd2dce75377860b97989d70a596a9c.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAZJHJ128F9310D14/343a27944d02a0bda11f798326430ed3.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAZJHJ128F9310D14/343a27944d02a0bda11f798326430ed3.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAZJHJ128F9310D14/343a27944d02a0bda11f798326430ed3.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAZJHJ128F9310D14/c105d0f437996f33e5305dcd3f4e6625.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAZJHJ128F9310D14/c105d0f437996f33e5305dcd3f4e6625.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAZJHJ128F9310D14/c105d0f437996f33e5305dcd3f4e6625.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAZLID128F93134B8/d95ae1e6a7a67521b64054ea80b84852.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAZLID128F93134B8/d95ae1e6a7a67521b64054ea80b84852.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAZLID128F93134B8/d95ae1e6a7a67521b64054ea80b84852.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRAZSJY128F92CCEA0/507775ba365a7c8225a362c26b4e4d03.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRAZSJY128F92CCEA0/507775ba365a7c8225a362c26b4e4d03.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRAZSJY128F92CCEA0/507775ba365a7c8225a362c26b4e4d03.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRBAMXF128F1470AD6/241fa3d3121641356dca3afbdcc34877.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRBAMXF128F1470AD6/241fa3d3121641356dca3afbdcc34877.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRBAMXF128F1470AD6/241fa3d3121641356dca3afbdcc34877.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRBAZCA128F4236C86/4a63b02361bc613f4c9cd8d9ba820ba8.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRBAZCA128F4236C86/4a63b02361bc613f4c9cd8d9ba820ba8.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRBAZCA128F4236C86/4a63b02361bc613f4c9cd8d9ba820ba8.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRBBTZW12903CE7495/01a400f01c65a687860801daf1320942.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRBBTZW12903CE7495/01a400f01c65a687860801daf1320942.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRBBTZW12903CE7495/01a400f01c65a687860801daf1320942.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRBGJMS128F4263C15/d8e571c3b96dded87088761c2b3f0765.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRBGJMS128F4263C15/d8e571c3b96dded87088761c2b3f0765.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRBGJMS128F4263C15/d8e571c3b96dded87088761c2b3f0765.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRBKPCE128F9320BBC/ee327d8884244fc86a1f9e2c6c6230c4.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRBKPCE128F9320BBC/ee327d8884244fc86a1f9e2c6c6230c4.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRBKPCE128F9320BBC/ee327d8884244fc86a1f9e2c6c6230c4.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRBNHPW128F4252572/25a898d48e87d6643bf74151d41e1a19.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRBNHPW128F4252572/25a898d48e87d6643bf74151d41e1a19.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRBNHPW128F4252572/25a898d48e87d6643bf74151d41e1a19.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRBNLHU128F14910D7/a14f09997143aca914303a316f4bb848.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRBNLHU128F14910D7/a14f09997143aca914303a316f4bb848.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRBNLHU128F14910D7/a14f09997143aca914303a316f4bb848.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRBOFTY128F14A37B1/2734cb37f071920a32efaa3042e4f641.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRBOFTY128F14A37B1/2734cb37f071920a32efaa3042e4f641.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRBOFTY128F14A37B1/2734cb37f071920a32efaa3042e4f641.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRBQKWY12903CDFC92/941daf712b66e830dbdbbb382f625754.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRBQKWY12903CDFC92/941daf712b66e830dbdbbb382f625754.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRBQKWY12903CDFC92/941daf712b66e830dbdbbb382f625754.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRBQNCM12903CD8BA0/b82285f12e8e5d26cd7fb136deda30ab.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRBQNCM12903CD8BA0/b82285f12e8e5d26cd7fb136deda30ab.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRBQNCM12903CD8BA0/b82285f12e8e5d26cd7fb136deda30ab.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRBSMHW128F92E385A/8a251640e95d9f781be01aac101f3fd3.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRBSMHW128F92E385A/8a251640e95d9f781be01aac101f3fd3.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRBSMHW128F92E385A/8a251640e95d9f781be01aac101f3fd3.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRBUMZC128F932009C/84ad0871ac9c525be379442da96ed3f5.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRBUMZC128F932009C/84ad0871ac9c525be379442da96ed3f5.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRBUMZC128F932009C/84ad0871ac9c525be379442da96ed3f5.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRBVFUF128F9310F4F/b2761ab0f4ce9a04dbbbc533b4ef2947.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRBVFUF128F9310F4F/b2761ab0f4ce9a04dbbbc533b4ef2947.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRBVFUF128F9310F4F/b2761ab0f4ce9a04dbbbc533b4ef2947.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRCEXWV128F92CFC50/0369695de3b81cef6769c2b869d9675c.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRCEXWV128F92CFC50/0369695de3b81cef6769c2b869d9675c.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRCEXWV128F92CFC50/0369695de3b81cef6769c2b869d9675c.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRCFRTP128F930276F/e8345f2fe6c087926f726464a12ea5fa.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRCFRTP128F930276F/e8345f2fe6c087926f726464a12ea5fa.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRCFRTP128F930276F/e8345f2fe6c087926f726464a12ea5fa.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRCFTCL128F92CF85E/8fd4d491cd3cbea45d20c1887eaf6e70.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRCFTCL128F92CF85E/8fd4d491cd3cbea45d20c1887eaf6e70.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRCFTCL128F92CF85E/8fd4d491cd3cbea45d20c1887eaf6e70.abc' returned non-zero exit status 1.
# Error executing command on ../../midi/lmd_matched_genre/TRCFVJF128F42AAD7B/909b69f03c36745129eab30ce518932d.mid: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRCFVJF128F42AAD7B/909b69f03c36745129eab30ce518932d.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRCFVJF128F42AAD7B/909b69f03c36745129eab30ce518932d.abc' returned non-zero exit status 1.
# ---------------------------------------------------------------------------
# TimeoutExpired                            Traceback (most recent call last)
# Cell In[5], line 13
#      10 os.makedirs(abc_folder, exist_ok=True)
#      12 try:
# ---> 13     subprocess.check_output(command, shell=True, timeout=3)
#      14 except subprocess.CalledProcessError as e:
#      15     wrong_files.append(midi_path)
#
# File C:/msys64/ucrt64/lib/python3.12/subprocess.py:468, in check_output(timeout, *popenargs, **kwargs)
#     465         empty = b''
#     466     kwargs['input'] = empty
# --> 468 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     469            **kwargs).stdout
#
# File C:/msys64/ucrt64/lib/python3.12/subprocess.py:552, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     550 with Popen(*popenargs, **kwargs) as process:
#     551     try:
# --> 552         stdout, stderr = process.communicate(input, timeout=timeout)
#     553     except TimeoutExpired as exc:
#     554         process.kill()
#
# File C:/msys64/ucrt64/lib/python3.12/subprocess.py:1211, in Popen.communicate(self, input, timeout)
#    1208     endtime = None
#    1210 try:
# -> 1211     stdout, stderr = self._communicate(input, endtime, timeout)
#    1212 except KeyboardInterrupt:
#    1213     # https://bugs.python.org/issue25942
#    1214     # See the detailed comment in .wait().
#    1215     if timeout is not None:
#
# File C:/msys64/ucrt64/lib/python3.12/subprocess.py:1632, in Popen._communicate(self, input, endtime, orig_timeout)
#    1630     self.stdout_thread.join(self._remaining_time(endtime))
#    1631     if self.stdout_thread.is_alive():
# -> 1632         raise TimeoutExpired(self.args, orig_timeout)
#    1633 if self.stderr is not None:
#    1634     self.stderr_thread.join(self._remaining_time(endtime))
#
# TimeoutExpired: Command 'midi2abc.exe -f ../../midi/lmd_matched_genre/TRCIJCU128E078E7DA/5bd3e0e419dd72eb10f6dab87cf7b09a.mid -aul 1 -k 0 -obpl -nogr -noly -o ../../midi/lmd_matched_flat_abc_test/TRCIJCU128E078E7DA/5bd3e0e419dd72eb10f6dab87cf7b09a.abc' timed out after 3 seconds

# %%
wrong_files

# %%
import json
with open("wrongs.json", "w") as wrongs_file:
    json.dump(wrong_files, wrongs_file)

# %% [markdown]
# # OLD

# %%
def get_channels(path):
    midi = mido.MidiFile(path)
    channels = set()

    for track in midi.tracks:
        for msg in track:
            if hasattr(msg, 'channel'):
                channels.add(msg.channel)
    
    return sorted(channels)

# %%
get_channels("lmd_matched_flat/TRAAAGR128F425B14B/1d9d16a9da90c090809c153754823c2b.mid")

# %%
def get_channel_instruments(path):
    midi = mido.MidiFile(path)
    channel_instruments = {}

    for track in midi.tracks:
        for msg in track:
            if msg.type == 'program_change':
                if hasattr(msg, 'channel'):
                    channel_instruments[msg.channel] = msg.program

    return {ch: prog for ch, prog in channel_instruments.items()}

# %%
get_channel_instruments("lmd_matched_flat/TRAAAGR128F425B14B/1d9d16a9da90c090809c153754823c2b.mid")

# %% [markdown]
# # Tests

# %%
os.makedirs?

# %% [markdown]
# # From MusicXML

# %%
import os
import music21

# %%
xml_root = "../../midi/lmd_matched_flat_musicxml_test"
abc_root = "../../midi/lmd_matched_flat_abc_test"

# %%
os.makedirs(abc_root)

# %%
wrong_files = []

# %%
for root, folders, files in os.walk(xml_root):
    for file in files:
        xml_path = os.path.join(root, file)
        abc_folder = os.path.join(abc_root, root.replace(xml_root + "/", ""))
        abc_path = os.path.join(abc_root, file.replace(".musicxml", ".abc"))

        os.makedirs(abc_folder, exist_ok=True)
        
        try:
            score = converter.parse(xml_path)
            abc_converter = ConverterABC()
            abc_text = abc_converter.codecWrite(score)
            with open(abc_path, 'w') as f:
                f.write(abc_text)
        except Exception as e:
            wrong_files.append(xml_path)
            print(f"Error executing command on {xml_path}: {e}")

# %%
wrong_files

# %%
import json
with open("wrongs.json", "w") as wrongs_file:
    json.dump(wrong_files, wrongs_file)
