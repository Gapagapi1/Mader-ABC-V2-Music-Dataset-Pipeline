# %%
import os
import mido
import subprocess

# %%
new_root = "lmd_matched_flat_merged_without_drums"
abc_root = "lmd_matched_flat_abc"

# %%
os.makedirs(abc_root)

# %%
wrong_files = []

# %%
for root, folders, files in os.walk(new_root):
    for file in files:
        midi_path = os.path.join(root, file)
        abc_folder = os.path.join(abc_root, root.replace(new_root + "/", ""))
        abc_path = os.path.join(abc_folder, file.replace(".midi", ".abc").replace(".mid", ".abc"))
        
        # L:1/1 | -K:C | one bar per line | no lyrics
        command = "midi2abc.exe -f {} -aul 1 -k 0 -obpl -nogr -noly -o {}".format(midi_path, abc_path)

        os.makedirs(abc_folder, exist_ok=True)
        
        try:
            # print(f"Executing: {command}")
            subprocess.run(command, shell=True, check=True)
        except subprocess.CalledProcessError as e:
            wrong_files.append(midi_path)
            print(f"Error executing command on {midi_path}: {e}")
# Out:
# Error executing command on lmd_matched_flat_merged_without_drums/TRAAMBM128F4248306/3caeffa7c12bf9dc85155ccd9a2f0c0c.mid: Command 'midi2abc.exe -f lmd_matched_flat_merged_without_drums/TRAAMBM128F4248306/3caeffa7c12bf9dc85155ccd9a2f0c0c.mid -aul 1 -k 0 -obpl -nogr -noly -o lmd_matched_flat_abc/TRAAMBM128F4248306/3caeffa7c12bf9dc85155ccd9a2f0c0c.abc' returned non-zero exit status 1.
# Error executing command on lmd_matched_flat_merged_without_drums/TRAAMBM128F4248306/54f5ee03fd4e2041e3cf2eb16137a3d7.mid: Command 'midi2abc.exe -f lmd_matched_flat_merged_without_drums/TRAAMBM128F4248306/54f5ee03fd4e2041e3cf2eb16137a3d7.mid -aul 1 -k 0 -obpl -nogr -noly -o lmd_matched_flat_abc/TRAAMBM128F4248306/54f5ee03fd4e2041e3cf2eb16137a3d7.abc' returned non-zero exit status 1.
# Error executing command on lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/02264fee9c66cda1a2b783a2fa85fdad.mid: Command 'midi2abc.exe -f lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/02264fee9c66cda1a2b783a2fa85fdad.mid -aul 1 -k 0 -obpl -nogr -noly -o lmd_matched_flat_abc/TRAAOPV128F92F7CE9/02264fee9c66cda1a2b783a2fa85fdad.abc' returned non-zero exit status 1.
# Error executing command on lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/4c67b066cbfb5b30bb046111e3ea6957.mid: Command 'midi2abc.exe -f lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/4c67b066cbfb5b30bb046111e3ea6957.mid -aul 1 -k 0 -obpl -nogr -noly -o lmd_matched_flat_abc/TRAAOPV128F92F7CE9/4c67b066cbfb5b30bb046111e3ea6957.abc' returned non-zero exit status 1.
# Error executing command on lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/5e4ba07ed939b155e396f0c546434ffd.mid: Command 'midi2abc.exe -f lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/5e4ba07ed939b155e396f0c546434ffd.mid -aul 1 -k 0 -obpl -nogr -noly -o lmd_matched_flat_abc/TRAAOPV128F92F7CE9/5e4ba07ed939b155e396f0c546434ffd.abc' returned non-zero exit status 1.
# Error executing command on lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/66432d9023e93145097a6e8392636c7f.mid: Command 'midi2abc.exe -f lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/66432d9023e93145097a6e8392636c7f.mid -aul 1 -k 0 -obpl -nogr -noly -o lmd_matched_flat_abc/TRAAOPV128F92F7CE9/66432d9023e93145097a6e8392636c7f.abc' returned non-zero exit status 1.
# Error executing command on lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/6723a65b641d110464e25413bb9094e4.mid: Command 'midi2abc.exe -f lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/6723a65b641d110464e25413bb9094e4.mid -aul 1 -k 0 -obpl -nogr -noly -o lmd_matched_flat_abc/TRAAOPV128F92F7CE9/6723a65b641d110464e25413bb9094e4.abc' returned non-zero exit status 1.
# Error executing command on lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/9b840ffe3a7daac4ebdb978276a97603.mid: Command 'midi2abc.exe -f lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/9b840ffe3a7daac4ebdb978276a97603.mid -aul 1 -k 0 -obpl -nogr -noly -o lmd_matched_flat_abc/TRAAOPV128F92F7CE9/9b840ffe3a7daac4ebdb978276a97603.abc' returned non-zero exit status 1.
# Error executing command on lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/b0f5ba935bcc8f78bb66a17074cd8eeb.mid: Command 'midi2abc.exe -f lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/b0f5ba935bcc8f78bb66a17074cd8eeb.mid -aul 1 -k 0 -obpl -nogr -noly -o lmd_matched_flat_abc/TRAAOPV128F92F7CE9/b0f5ba935bcc8f78bb66a17074cd8eeb.abc' returned non-zero exit status 1.
# Error executing command on lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/bfe0f03d8ef3ed256c6dff98f6abe33d.mid: Command 'midi2abc.exe -f lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/bfe0f03d8ef3ed256c6dff98f6abe33d.mid -aul 1 -k 0 -obpl -nogr -noly -o lmd_matched_flat_abc/TRAAOPV128F92F7CE9/bfe0f03d8ef3ed256c6dff98f6abe33d.abc' returned non-zero exit status 1.
# Error executing command on lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/c41f5366781232b3b3d74d73e6baa737.mid: Command 'midi2abc.exe -f lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/c41f5366781232b3b3d74d73e6baa737.mid -aul 1 -k 0 -obpl -nogr -noly -o lmd_matched_flat_abc/TRAAOPV128F92F7CE9/c41f5366781232b3b3d74d73e6baa737.abc' returned non-zero exit status 1.
# Error executing command on lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/d83c7c3b191c26fee8e8316c6a51d782.mid: Command 'midi2abc.exe -f lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/d83c7c3b191c26fee8e8316c6a51d782.mid -aul 1 -k 0 -obpl -nogr -noly -o lmd_matched_flat_abc/TRAAOPV128F92F7CE9/d83c7c3b191c26fee8e8316c6a51d782.abc' returned non-zero exit status 1.
# Error executing command on lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/eec4d57062749f9c2682f6326c189f80.mid: Command 'midi2abc.exe -f lmd_matched_flat_merged_without_drums/TRAAOPV128F92F7CE9/eec4d57062749f9c2682f6326c189f80.mid -aul 1 -k 0 -obpl -nogr -noly -o lmd_matched_flat_abc/TRAAOPV128F92F7CE9/eec4d57062749f9c2682f6326c189f80.abc' returned non-zero exit status 1.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 14
#      10 os.makedirs(abc_folder, exist_ok=True)
#      12 try:
#      13     # print(f"Executing: {command}")
# ---> 14     subprocess.run(command, shell=True, check=True)
#      15 except subprocess.CalledProcessError as e:
#      16     wrong_files.append(midi_path)
#
# File F:/msys64/ucrt64/lib/python3.12/subprocess.py:552, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     550 with Popen(*popenargs, **kwargs) as process:
#     551     try:
# --> 552         stdout, stderr = process.communicate(input, timeout=timeout)
#     553     except TimeoutExpired as exc:
#     554         process.kill()
#
# File F:/msys64/ucrt64/lib/python3.12/subprocess.py:1203, in Popen.communicate(self, input, timeout)
#    1201         stderr = self.stderr.read()
#    1202         self.stderr.close()
# -> 1203     self.wait()
#    1204 else:
#    1205     if timeout is not None:
#
# File F:/msys64/ucrt64/lib/python3.12/subprocess.py:1266, in Popen.wait(self, timeout)
#    1264     endtime = _time() + timeout
#    1265 try:
# -> 1266     return self._wait(timeout=timeout)
#    1267 except KeyboardInterrupt:
#    1268     # https://bugs.python.org/issue25942
#    1269     # The first keyboard interrupt waits briefly for the child to
#    1270     # exit under the common assumption that it also received the ^C
#    1271     # generated SIGINT and will exit rapidly.
#    1272     if timeout is not None:
#
# File F:/msys64/ucrt64/lib/python3.12/subprocess.py:1592, in Popen._wait(self, timeout)
#    1589     timeout_millis = int(timeout * 1000)
#    1590 if self.returncode is None:
#    1591     # API note: Returns immediately if timeout_millis == 0.
# -> 1592     result = _winapi.WaitForSingleObject(self._handle,
#    1593                                          timeout_millis)
#    1594     if result == _winapi.WAIT_TIMEOUT:
#    1595         raise TimeoutExpired(self.args, timeout)
#
# KeyboardInterrupt:

# %%
wrong_files

# %%
import json
with open("wrongs.json", "w") as wrongs_file:
    json.dump(wrong_files, wrongs_file)

# %% [markdown]
# # OLD

# %%
def get_channels(path):
    midi = mido.MidiFile(path)
    channels = set()

    for track in midi.tracks:
        for msg in track:
            if hasattr(msg, 'channel'):
                channels.add(msg.channel)
    
    return sorted(channels)

# %%
get_channels("lmd_matched_flat/TRAAAGR128F425B14B/1d9d16a9da90c090809c153754823c2b.mid")

# %%
def get_channel_instruments(path):
    midi = mido.MidiFile(path)
    channel_instruments = {}

    for track in midi.tracks:
        for msg in track:
            if msg.type == 'program_change':
                if hasattr(msg, 'channel'):
                    channel_instruments[msg.channel] = msg.program

    return {ch: prog for ch, prog in channel_instruments.items()}

# %%
get_channel_instruments("lmd_matched_flat/TRAAAGR128F425B14B/1d9d16a9da90c090809c153754823c2b.mid")

# %% [markdown]
# # Tests

# %%
os.makedirs?
